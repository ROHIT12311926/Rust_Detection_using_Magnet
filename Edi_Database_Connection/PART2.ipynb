# %%
import joblib
import pandas as pd

model = joblib.load("rust_detection_rf_pipeline.pkl")

# %%
sample = {
    'Material': ['CRC'],
    'Length': [11],
    'Width': [11],
    'X': [196.38],
    'Y': [42.08],
    'Z': [32.29],
    'Resultant': [181.42]
}

sample_df = pd.DataFrame(sample)

# %%
pred = model.predict(sample_df)
print("Prediction:", pred[0])
# Out:
# Prediction: NON-RUSTED
